# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
#Visualizar conjuntos difusos
demanda = ctrl.Antecedent(np.arange(5, 51, 1), 'demanda')
demanda['baja'] = fuzz.sigmf(demanda.universe,30,-0.6)
demanda['media'] = fuzz.gaussmf(demanda.universe, 36, 4)
demanda['alta'] = fuzz.sigmf(demanda.universe,42,0.6)
demanda.view()
# Out:
# c:\Users\camil\Documents\GitHub\LogicaDifusa\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:125: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
#Tiempo de reabasteceimiento
tiempo = ctrl.Antecedent(np.arange(8, 73, 1), 'tiempo')
tiempo['bajo'] = fuzz.sigmf(tiempo.universe,24,-0.6)
tiempo['medio'] = fuzz.gaussmf(tiempo.universe, 30, 4)
tiempo['alto'] = fuzz.sigmf(tiempo.universe,36,0.6)
tiempo.view()

# %%
#Stock
stock = ctrl.Consequent(np.arange(70, 201, 1), 'stock')
stock['bajo'] = fuzz.sigmf(stock.universe,110,-0.2)
stock['medio'] = fuzz.gaussmf(stock.universe, 130, 10)
stock['alto'] = fuzz.sigmf(stock.universe,150,0.2)
stock.view()

# %%
#Declaracion antececentes
demanda = ctrl.Antecedent(np.arange(5, 51, 1), 'demanda')
demanda_baja = fuzz.sigmf(demanda.universe,30,-0.6)
demanda_media = fuzz.gaussmf(demanda.universe, 36, 4)
demanda_alta = fuzz.sigmf(demanda.universe,42,0.6)

tiempo = ctrl.Antecedent(np.arange(8, 73, 1), 'tiempo')
tiempo_bajo = fuzz.sigmf(tiempo.universe,24,-0.6)
tiempo_medio = fuzz.gaussmf(tiempo.universe, 30, 4)
tiempo_alto = fuzz.sigmf(tiempo.universe,36,0.6)

stock = ctrl.Consequent(np.arange(70, 201, 1), 'stock')
stock_bajo = fuzz.sigmf(stock.universe,110,-0.2)
stock_medio = fuzz.gaussmf(stock.universe, 130, 10)
stock_alto = fuzz.sigmf(stock.universe,150,0.2)

# %%
#Funciones del consecuente
l1 = linregress([5, 30], [300, 450])
l2 = linregress([30, 42], [450, 780])
l3 = linregress([42, 50], [780, 900])

l4 = linregress([8, 24], [300, 450])
l5 = linregress([24, 36], [450, 780])
l6 = linregress([36, 72], [780, 900])

l7 = linregress([70, 110], [300, 450])
l8 = linregress([110, 150], [450, 780])
l9 = linregress([150, 200], [780, 900])

m1 = l1.slope
b1 = l1.intercept
m2 = l2.slope
b2 = l2.intercept
m3 = l3.slope
b3 = l3.intercept
m4 = l4.slope
b4 = l4.intercept
m5 = l5.slope
b5 = l5.intercept
m6 = l6.slope
b6 = l6.intercept
m7 = l7.slope
b7 = l7.intercept
m8 = l8.slope
b8 = l8.intercept
m9 = l9.slope
b9 = l9.intercept

#Definir Funciones
def p147(d, s, t):
    return m1 * d + b1 + m4 * t + b4 + m7 * s + b7

def p148(d, s, t):
    return m1 * d + b1 + m4 * t + b4 + m8 * s + b8

def p149(d, s, t):
    return m1 * d + b1 + m4 * t + b4 + m9 * s + b9

def p157(d, s, t):
    return m1 * d + b1 + m5 * t + b5 + m7 * s + b7

def p158(d, s, t):
    return m1 * d + b1 + m5 * t + b5 + m8 * s + b8

def p159(d, s, t):
    return m1 * d + b1 + m5 * t + b5 + m9 * s + b9

def p167(d, s, t):
    return m1 * d + b1 + m6 * t + b6 + m7 * s + b7

def p168(d, s, t):
    return m1 * d + b1 + m6 * t + b6 + m8 * s + b8

def p169(d, s, t):
    return m1 * d + b1 + m6 * t + b6 + m9 * s + b9

def p247(d, s, t):
    return m2 * d + b2 + m4 * t + b4 + m7 * s + b7

def p248(d, s, t):
    return m2 * d + b2 + m4 * t + b4 + m8 * s + b8

def p249(d, s, t):
    return m2 * d + b2 + m4 * t + b4 + m9 * s + b9

def p257(d, s, t):
    return m2 * d + b2 + m5 * t + b5 + m7 * s + b7

def p258(d, s, t):
    return m2 * d + b2 + m5 * t + b5 + m8 * s + b8

def p259(d, s, t):
    return m2 * d + b2 + m5 * t + b5 + m9 * s + b9

def p267(d, s, t):
    return m2 * d + b2 + m6 * t + b6 + m7 * s + b7

def p268(d, s, t):
    return m2 * d + b2 + m6 * t + b6 + m8 * s + b8

def p269(d, s, t):
    return m2 * d + b2 + m6 * t + b6 + m9 * s + b9

def p347(d, s, t):
    return m3 * d + b3 + m4 * t + b4 + m7 * s + b7

def p348(d, s, t):
    return m3 * d + b3 + m4 * t + b4 + m8 * s + b8

def p349(d, s, t):
    return m3 * d + b3 + m4 * t + b4 + m9 * s + b9

def p357(d, s, t):
    return m3 * d + b3 + m5 * t + b5 + m7 * s + b7

def p358(d, s, t):
    return m3 * d + b3 + m5 * t + b5 + m8 * s + b8

def p359(d, s, t):
    return m3 * d + b3 + m5 * t + b5 + m9 * s + b9

def p367(d, s, t):
    return m3 * d + b3 + m6 * t + b6 + m7 * s + b7

def p368(d, s, t):
    return m3 * d + b3 + m6 * t + b6 + m8 * s + b8

def p369(d, s, t):
    return m3 * d + b3 + m6 * t + b6 + m9 * s + b9

# %%
#Base de conocimiento
def regla1(d, t, s):
    mu1 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu1

def regla2(d, t, s):
    mu2 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu2

def regla3(d, t, s):
    mu3 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu3

def regla4(d, t, s):
    mu4 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu4

def regla5(d, t, s):
    mu5 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu5

def regla6(d, t, s):
    mu6 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu6

def regla7(d, t, s):
    mu7 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu7

def regla8(d, t, s):
    mu8 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu8

def regla9(d, t, s):
    mu9 = min(max(fuzz.interp_membership(demanda.universe, demanda_baja, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu9

def regla10(d, t, s):
    mu10 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu10

def regla11(d, t, s):
    mu11 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu11

def regla12(d, t, s):
    mu12 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu12

def regla13(d, t, s):
    mu13 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu13

def regla14(d, t, s):
    mu14 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu14

def regla15(d, t, s):
    mu15 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu15

def regla16(d, t, s):
    mu16 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu16

def regla17(d, t, s):
    mu17 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu17

def regla18(d, t, s):
    mu18 = min(max(fuzz.interp_membership(demanda.universe, demanda_media, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu18

def regla19(d, t, s):
    mu19 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu19

def regla20(d, t, s):
    mu20 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu20

def regla21(d, t, s):
    mu21 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_bajo, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu21

def regla22(d, t, s):
    mu22 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu22

def regla23(d, t, s):
    mu23 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu23

def regla24(d, t, s):
    mu24 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_medio, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu24

def regla25(d, t, s):
    mu25 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_bajo, t))
    return mu25

def regla26(d, t, s):
    mu26 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_medio, t))
    return mu26

def regla27(d, t, s):
    mu27 = min(max(fuzz.interp_membership(demanda.universe, demanda_alta, d), fuzz.interp_membership(stock.universe, stock_alto, s)), fuzz.interp_membership(tiempo.universe, tiempo_alto, t))
    return mu27

# %%
#Deffuzificacion

def deffuzificacion(d,t,s):
    mu1 = regla1(d,t,s)
    mu2 = regla2(d,t,s)
    mu3 = regla3(d,t,s)
    mu4 = regla4(d,t,s)
    mu5 = regla5(d,t,s)
    mu6 = regla6(d,t,s)
    mu7 = regla7(d,t,s)
    mu8 = regla8(d,t,s)
    mu9 = regla9(d,t,s)
    mu10 = regla10(d,t,s)
    mu11 = regla11(d,t,s)
    mu12 = regla12(d,t,s)
    mu13 = regla13(d,t,s)
    mu14 = regla14(d,t,s)
    mu15 = regla15(d,t,s)
    mu16 = regla16(d,t,s)
    mu17 = regla17(d,t,s)
    mu18 = regla18(d,t,s)
    mu19 = regla19(d,t,s)
    mu20 = regla20(d,t,s)
    mu21 = regla21(d,t,s)
    mu22 = regla22(d,t,s)
    mu23 = regla23(d,t,s)
    mu24 = regla24(d,t,s)
    mu25 = regla25(d,t,s)
    mu26 = regla26(d,t,s)
    mu27 = regla27(d,t,s)

    r_147 = p147(d, s, t)
    r_148 = p148(d, s, t)
    r_149 = p149(d, s, t)
    r_157 = p157(d, s, t)
    r_158 = p158(d, s, t)
    r_159 = p159(d, s, t)
    r_167 = p167(d, s, t)
    r_168 = p168(d, s, t)
    r_169 = p169(d, s, t)
    r_247 = p247(d, s, t)
    r_248 = p248(d, s, t)
    r_249 = p249(d, s, t)
    r_257 = p257(d, s, t)
    r_258 = p258(d, s, t)
    r_259 = p259(d, s, t)
    r_267 = p267(d, s, t)
    r_268 = p268(d, s, t)
    r_269 = p269(d, s, t)
    r_347 = p347(d, s, t)
    r_348 = p348(d, s, t)
    r_349 = p349(d, s, t)
    r_357 = p357(d, s, t)
    r_358 = p358(d, s, t)
    r_359 = p359(d, s, t)
    r_367 = p367(d, s, t)
    r_368 = p368(d, s, t)
    r_369 = p369(d, s, t)

    return (mu1*r_147 + mu2*r_148 + mu3*r_149 + mu4*r_157 + mu5*r_158 + mu6*r_159 + mu7*r_167 + mu8*r_168 + mu9*r_169 + mu10*r_247 + mu11*r_248 + mu12*r_249 + mu13*r_257 + mu14*r_258 + mu15*r_259 + mu16*r_267 + mu17*r_268 + mu18*r_269 + mu19*r_347 + mu20*r_348 + mu21*r_349 + mu22*r_357 + mu23*r_358 + mu24*r_359 + mu25*r_367 + mu26*r_368 + mu27*r_369)/(mu1 + mu2 + mu3 + mu4 + mu5 + mu6 + mu7 + mu8 + mu9 + mu10 + mu11 + mu12 + mu13 + mu14 + mu15 + mu16 + mu17 + mu18 + mu19 + mu20 + mu21 + mu22 + mu23 + mu24 + mu25 + mu26 + mu27)

# %%
deffuzificacion(12,28,82)

def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

y_true = 420
y_pred = deffuzificacion(12,28,82)
print(y_pred)
mape(y_true, y_pred)
# Out:
# 1050.4632743693567
# np.float64(150.1103034212754)
